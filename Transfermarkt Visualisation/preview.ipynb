# %% [markdown]
# # Démonstration de la carte

# %% [markdown]
# Ce fichier est à tester sur votre PC si vous voulez le tester pour différents clubs, les librairies à avoir sont :
# -folium
# -json
# -collections
#
# Sinon le fichier templates/transferts.html a été généré pour vous permettre de voir le résultat de ce travail

# %%
import map_transferts as mptr
import dtmaplib as mplib

# %%
mptr.init_map_club("Olympique de Marseille")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mptr.transferts[:2]
# Out:
# [{'nomJoueur': 'Erling Haaland',
#   'nomClubAcheteur': 'Manchester City',
#   'nomClubVendeur': 'Bor. Dortmund',
#   'prix': '60,00 mio. €'},
#  {'nomJoueur': 'Raheem Sterling',
#   'nomClubAcheteur': 'Chelsea',
#   'nomClubVendeur': 'Manchester City',
#   'prix': '56,20 mio. €'}]

# %%
mplib.clubs[:1]
# Out:
# [{'nomClub': 'Manchester City',
#   'valeurMarchande': '1,09 mrd. ',
#   'effectifTaille': '23',
#   'bilanTransfert': '+20,40 mio. €',
#   'nbJoueurEtrangers': '16',
#   'prcntJoueurEtrangers': '69,6 %',
#   'nomStade': 'Etihad Stadium',
#   'ageMoyen': '27,3',
#   'photo': 'https://tmssl.akamaized.net/images/wappen/head/281.png?lm=1467356331',
#   'localisation': '[-2.2003953, 53.4831381]',
#   'effectif': ['Ederson',
#    'Stefan Ortega',
#    'Scott Carson',
#    'Rúben Dias',
#    'Aymeric Laporte',
#    'John Stones',
#    'Nathan Aké',
#    'Manuel Akanji',
#    'Sergio Gómez',
#    'João Cancelo',
#    'Kyle Walker',
#    'Rodri',
#    'Kalvin Phillips',
#    'Phil Foden',
#    'Ilkay Gündogan',
#    'Kevin De Bruyne',
#    'Bernardo Silva',
#    'Cole Palmer',
#    'Jack Grealish',
#    'Riyad Mahrez',
#    'Erling Haaland',
#    'Julián Álvarez']}]

# %%
mplib.joueurs[:1]
# Out:
# [{'dataJoueur': {'nom': 'Ederson',
#    'nomComplet': 'Ederson Santana de Moraes',
#    'dateDeNaissance': '17 août 1993',
#    'lieuDeNaissance': 'Osasco (SP)',
#    'age': '29',
#    'taille': '1,88\xa0m',
#    'nationalite': 'Brésil\xa0\xa0Portugal',
#    'position': 'Gardien',
#    'bonPied': 'gauche',
#    'agentDuJoueur': 'Gestifute',
#    'club': 'Manchester City',
#    'debutContrat': '1 juil. 2017',
#    'finContrat': '30 juin 2026',
#    'optionContrat': '-',
#    'equipementier': 'Puma',
#    'photo': 'https://img.a.transfermarkt.technology/portrait/header/238223-1661978747.jpg?lm=1',
#    'valeurMarchande': '45,00 mio. €'},
#   'HistoriqueJoueur': {'montantTotal': '40,50 mio. €',
#    'tabTransfert': [{'saison': 'Saison',
#      'date': 'Date',
#      'vendeur': 'Benfica',
#      'acheteur': 'Manchester City',
#      'valeurMarchande': '22,00 mio. €',
#      'montant': '40,00 mio. €'},
#     {'saison': '17/18',
#      'date': '1 juil. 2017',
# ...
